# %%
import json
import pandas as pd
json_file_path = 'cluster13_maxSpanningTree.json'
cluster_13_dict = {}

with open(json_file_path, 'r') as file:
    cluster_13_dict = json.load(file)

# %%
cluster_13_dict
# Out:
# {'Kate Symes': {'Portland Shift': 14.0,
#   'Mark Guzman': 49.0,
#   'Bill Williams III': 76.0,
#   'Kerri Thompson': 859.0,
#   'Kimberly Hundl': 248.0,
#   'Sharen Cason': 382.0,
#   'Stephanie Piwetz': 391.0,
#   'David Poston': 11.0,
#   'Amy FitzPatrick': 38.0,
#   'Lester Rawson': 108.0,
#   'Cara Semperger': 74.0,
#   'Joy Werner': 4.0,
#   'Evelyn Metoyer': 915.0,
#   'Mollie Gustafson': 69.0,
#   'Geir Solberg': 4.0,
#   'Melissa Ann Murphy': 139.0,
#   'Angela Cadena': 29.0,
#   'Rhonda L Denton': 167.0,
#   'Winston Goodbody': 28.0,
#   'Stanley Cocke': 12.0,
#   'Kimberly Indelicato': 28.0,
#   'Duong Luu': 8.0,
#   'Jeffrey Oh': 7.0,
#   'Jeff Richter': 4.0,
#   'John M Forney': 4.0,
#   'Leaf Harasin': 8.0,
#   'Elliot Mainzer': 8.0,
#   'Teri Whitcomb': 7.0,
#   'Veronica Gonzalez': 8.0,
#   'Debra Davidson': 4.0,
#   'Chip Cox': 3.0,
#   'Andy Chen': 10.0,
#   'Daniel Kang': 8.0,
#   'Judy Dyer': 24.0,
#   'Kimberly Allen': 92.0,
#   'Katrina Johnson': 4.0,
# ...

# %%
cluster_max_list = [(sender, receiver, exchange) for sender, receivers in cluster_13_dict.items() for receiver, exchange in receivers.items()]

# %%
cluster_max_sepate_df = pd.DataFrame(cluster_max_list, columns=['Sender', 'Receiver', 'Number of Information Exchange'])

# %%
cluster_max_sepate_df
# Out:
#             Sender           Receiver  Number of Information Exchange
# 0       Kate Symes     Portland Shift                            14.0
# 1       Kate Symes        Mark Guzman                            49.0
# 2       Kate Symes  Bill Williams III                            76.0
# 3       Kate Symes     Kerri Thompson                           859.0
# 4       Kate Symes     Kimberly Hundl                           248.0
# ..             ...                ...                             ...
# 79      Kate Symes    Andrew Hawthorn                             4.0
# 80      Kate Symes      Jubran Whalan                             8.0
# 81      Kate Symes    Nadine Costanzo                             4.0
# 82      Kate Symes       Jonalan Page                             4.0
# 83  Kerri Thompson      Carla Hoffman                            15.0
#
# [84 rows x 3 columns]

# %% [markdown]
# # Query another dictionary

# %%
path = 'emails_cleaned.csv'
text_df = pd.read_csv(path)

# %%
text_senderRecieverTextdf =text_df[['X-From','X-To','content']]

# %%
text_senderRecieverTextdf
# Out:
#                 X-From              X-To  \
# 0      Richard Shapiro     Leslie Lawner
# 1      Richard Shapiro     Leslie Lawner
# 2           Dan J Hyvl         Eric Bass
# 3           Dan J Hyvl         Eric Bass
# 4           Dan J Hyvl         Eric Bass
# ...                ...               ...
# 70092       Tana Jones       Dave Fuller
# 70093       Tana Jones       Dave Fuller
# 70094       Tana Jones  Jason R Williams
# 70095       Tana Jones  Jason R Williams
# 70096       Tana Jones       Dave Fuller
#
#                                                  content
# 0      Leslie,after seeing point # 3 in writing , I w...
# 1      Leslie,after seeing point # 3 in writing , I w...
# 2      Please see item 8 of the attached GTC.  When t...
# 3      Please see item 8 of the attached GTC.  When t...
# 4      Please see item 8 of the attached GTC.  When t...
# ...                                                  ...
# 70092  Dave,\n\nAttached is the Schedule to the ISDA ...
# ...

# %% [markdown]
# Preoprocessing

# %%
#remove digiu
text_senderRecieverTextdf['content'] = text_senderRecieverTextdf['content'].str.replace(r'\d+', '', regex=True)
# Out:
# /var/folders/j4/s37rcpps3kj5ktfxvqhqq3_m0000gn/T/ipykernel_74147/3184462352.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   text_senderRecieverTextdf['content'] = text_senderRecieverTextdf['content'].str.replace(r'\d+', '', regex=True)

# %%
# NLP text removal package
import pandas as pd
import neattext.functions as nfx

# %%
# text type transformation
text_senderRecieverTextdf['content'] =text_senderRecieverTextdf['content'] .astype(str)
# Out:
# /var/folders/j4/s37rcpps3kj5ktfxvqhqq3_m0000gn/T/ipykernel_74147/230674828.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   text_senderRecieverTextdf['content'] =text_senderRecieverTextdf['content'] .astype(str)

# %%
# Clean Text:stopwords,special charac
text_senderRecieverTextdf['content'] = text_senderRecieverTextdf['content'].apply(nfx.remove_stopwords)
# Clean Text:stopwords,special charac
text_senderRecieverTextdf['content'] = text_senderRecieverTextdf['content'].apply(nfx.remove_special_characters)
# Out:
# /var/folders/j4/s37rcpps3kj5ktfxvqhqq3_m0000gn/T/ipykernel_74147/1151673196.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   text_senderRecieverTextdf['content'] = text_senderRecieverTextdf['content'].apply(nfx.remove_stopwords)
# /var/folders/j4/s37rcpps3kj5ktfxvqhqq3_m0000gn/T/ipykernel_74147/1151673196.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   text_senderRecieverTextdf['content'] = text_senderRecieverTextdf['content'].apply(nfx.remove_special_characters)

# %%
text_senderRecieverTextdf
# Out:
#                 X-From              X-To  \
# 0      Richard Shapiro     Leslie Lawner
# 1      Richard Shapiro     Leslie Lawner
# 2           Dan J Hyvl         Eric Bass
# 3           Dan J Hyvl         Eric Bass
# 4           Dan J Hyvl         Eric Bass
# ...                ...               ...
# 70092       Tana Jones       Dave Fuller
# 70093       Tana Jones       Dave Fuller
# 70094       Tana Jones  Jason R Williams
# 70095       Tana Jones  Jason R Williams
# 70096       Tana Jones       Dave Fuller
#
#                                                  content
# 0      Leslieafter seeing point  writing  extremely r...
# 1      Leslieafter seeing point  writing  extremely r...
# 2      item attached GTC outside party provide Gas al...
# 3      item attached GTC outside party provide Gas al...
# 4      item attached GTC outside party provide Gas al...
# ...                                                  ...
# 70092  Dave Attached Schedule ISDA Master Agreement d...
# ...

# %% [markdown]
# Compare

# %%
cluster_max_sepate_df
# Out:
#             Sender           Receiver  Number of Information Exchange
# 0       Kate Symes     Portland Shift                            14.0
# 1       Kate Symes        Mark Guzman                            49.0
# 2       Kate Symes  Bill Williams III                            76.0
# 3       Kate Symes     Kerri Thompson                           859.0
# 4       Kate Symes     Kimberly Hundl                           248.0
# ..             ...                ...                             ...
# 79      Kate Symes    Andrew Hawthorn                             4.0
# 80      Kate Symes      Jubran Whalan                             8.0
# 81      Kate Symes    Nadine Costanzo                             4.0
# 82      Kate Symes       Jonalan Page                             4.0
# 83  Kerri Thompson      Carla Hoffman                            15.0
#
# [84 rows x 3 columns]

# %%
max_weight_row = cluster_max_sepate_df[cluster_max_sepate_df['Number of Information Exchange'] == cluster_max_sepate_df['Number of Information Exchange'].max()]

# %%
sender_fromMax = max_weight_row['Sender'].tolist()[0]
receiver_fromMax = max_weight_row['Receiver'].tolist()[0]

# %%
#query for the text in 
maxFlowEDGEDF = text_senderRecieverTextdf[(text_senderRecieverTextdf['X-From'] == sender_fromMax) & 
                                      (text_senderRecieverTextdf['X-To'] == receiver_fromMax)]

# %%
maxFlowEDGEDF
# Out:
#            X-From            X-To  \
# 61732  Kate Symes  Evelyn Metoyer
# 61752  Kate Symes  Evelyn Metoyer
# 61758  Kate Symes  Evelyn Metoyer
# 61763  Kate Symes  Evelyn Metoyer
# 61779  Kate Symes  Evelyn Metoyer
# ...           ...             ...
# 67540  Kate Symes  Evelyn Metoyer
# 67560  Kate Symes  Evelyn Metoyer
# 67564  Kate Symes  Evelyn Metoyer
# 67566  Kate Symes  Evelyn Metoyer
# 67569  Kate Symes  Evelyn Metoyer
#
#                                                  content
# 61732  right  Im changing deal right now Thanks Kate ...
# 61752  deal changed Thanks Kate Evelyn MetoyerENRON  ...
# 61758  checked deals broker fee Mark Fischer changed ...
# 61763  deal changed AEP Thanks Kate Evelyn MetoyerENR...
# 61779  guess going mad pace today checked Amerex brok...
# ...                                                  ...
# 67540  Thats weird traded nearly low April today Mike...
# 67560  Ive left message Jeff cant find trade log anyw...
# ...

# %%
max_edge_simiality_list = maxFlowEDGEDF['content'].tolist()

# %%
max_edge_simiality_list
# Out:
# ['right  Im changing deal right now Thanks Kate Evelyn MetoyerENRON   PM To Kate SymesPDXECTECT cc Subject  discrepancies Mike Swerzbin deal Prebon shows term Cal instead Cal Thanks',
#  'deal changed Thanks Kate Evelyn MetoyerENRON   PM To Kate SymesPDXECTECT cc Subject  discrepancies Bob Badeer deal Prebon price  instead  Thanks',
#  'checked deals broker fee Mark Fischer changed this let know showing system Thanks kate Evelyn MetoyerENRON   To Kate SymesPDXECTECT cc Subject Fee discrepancies Mark Fischer traded  deals Amerex shows fee deals  Thanks',
#  'deal changed AEP Thanks Kate Evelyn MetoyerENRON   PM To Kate SymesPDXECTECT cc Subject  Discrepancies Matt Motley ref Amerex shows cp AEP Sempra',
# ...

# %%
# Construct another list
senderName  ='Kate Symes'
receiverName = 'Mark Guzman'

# %%
#query for the text in 
anotherEdge = text_senderRecieverTextdf[(text_senderRecieverTextdf['X-From'] == senderName) & 
                                      (text_senderRecieverTextdf['X-To'] == receiverName)]

# %%
anotheredge_simiality_list = anotherEdge['content'].tolist()

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np
list_1_compared = max_edge_simiality_list
list_2_compared = anotheredge_simiality_list
combined_texts = list_1_compared + list_2_compared
tf_vectorizer = TfidfVectorizer()
tfidf_matrix = tf_vectorizer.fit_transform(combined_texts)
cosine_sim_matrix = cosine_similarity(tfidf_matrix[:len(list_1_compared)], tfidf_matrix[len(list_1_compared):])
average_similarity = np.mean(cosine_sim_matrix)
print("Average Cosine Similarity:", average_similarity)
# Out:
# Average Cosine Similarity: 0.025128691857783023
